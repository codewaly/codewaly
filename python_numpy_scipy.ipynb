# %%
import math
import numpy as np
from sklearn import linear_model
from os import mkdir

# %% [markdown]
# ##### $1.$  Écrire une fonction nextpower qui calcule la première puissance de $2$ supérieure ou égale à un nombre $n.$

# %%
def nextpower(n):
    k=0
    nextpower=1
    while n > nextpower :
        k=k+1
        nextpower=2**k
    return k

# %%
print(nextpower(5))
# Out:
# 3

# %% [markdown]
# ##### $2.$ En partant du mot contenant toutes les lettres de l’alphabet, générer par une opération de slicing la chaîne de caractère cfilorux et, de deux façons différentes, la chaîne de caractère vxz.

# %%
mot='abcdefghijklmnopqrstuvwxyz'

# %%
mot_1 = mot[2: :3]

# %% [markdown]
# ###### Première façon pour obtenir vxz

# %%
mot_2 = mot[21 : : 2]

# %%
print(mot_2)
# Out:
# vxz

# %%
mot_2_bis = mot[21:26:2]

# %%
Ind=[21,23,25]
mot_12=''
for i in Ind:
    mot_12=mot_12+mot[i]

# %% [markdown]
# ##### 3. Afficher le nombre $\pi$ avec $9$ décimales après la virgule.

# %%
nombre =  round(math.pi,9)

# %% [markdown]
# ##### $4.$ Compter le nombre d’occurrences de chaque caractère dans la chaîne de caractères s="HelLo WorLd!!".

# %%
s = "Hello Worlf"
h = s.count("H")
e = s.count("e")
l= s.count("l")

# %% [markdown]
# ##### $5.$ Écrire une fonction de codage par inversion de lettres 1 : chaque lettre d’un mot est remplacée par une (et une seule) autre. On se servira de la fonction shuffle sur la chaîne de caractères contenant tout l’alphabet pour associer les lettres codées.

# %%
import random
def codage()
mot='abcdefghijklmnopqrstuvwxyz'
liste=list(mot)
random.shuffle(liste)
liste = "".join(liste)

# %%
print(liste)
# Out:
# bdiuvlnosezhjmxrtcykqfwagp

# %%
def codage_inversion(str):
    if len(str)<=1:
        result = str
    else:
